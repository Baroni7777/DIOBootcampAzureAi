# %%
# !pip install requests beautifulsoup4 openai langchain-openai
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.6/50.6 kB 1.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 409.5/409.5 kB 8.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 19.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.3.19
#     Uninstalling langchain-core-0.3.19:
#       Successfully uninstalled langchain-core-0.3.19
# ...

# %%
import requests
from bs4 import BeautifulSoup

def extract_text_from_url(url):
    response = requests.get(url)

    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')

        for script_or_style in soup(['script', 'style']):
            script_or_style.decompose()

        texto = soup.get_text(separator=' ')

        # Limpar texto
        linhas = (line.strip() for line in texto.splitlines())
        parts = (phrase.strip() for line in linhas for phrase in line.split("  "))
        texto_limpo = '\n'.join(part for part in parts if part)
        return texto_limpo
    else:
        print(f"Failed to fetch the URL. Status code: {response.status_code}")
        return None

        text = soup.get_text()
    return text

extract_text_from_url('https://dev.to/nevodavid/i-am-making-700-monthly-with-my-open-source-scheduling-tool-you-can-do-it-too-33o7')
# Out:
# 'I am making $700 monthly with my open-source scheduling tool - you can do it too! - DEV Community\nSkip to content\nNavigation menu\nSearch\nPowered by\nSearch\nAlgolia\nSearch\nLog in\nCreate account\nDEV Community\nClose\nAdd reaction\nLike\nUnicorn\nExploding Head\nRaised Hands\nFire\nJump to Comments\nSave\nMore...\nCopy link\nCopy link\nCopied to Clipboard\nShare to X\nShare to LinkedIn\nShare to Facebook\nShare to Mastodon\nReport Abuse\nNevo David\nPosted on\nNov 26\nI am making $700 monthly with my open-source scheduling tool - you can do it too!\n# webdev\n# programming\n# tutorial\n# javascript\nI am a big advocate of open-source startups. Over the next year, you will see many more of them. You take an existing product and open-source it.\nI built a social media scheduling tool (many exist in the market) and created an open-source version.\nThis is\nPostiz , an open-source social media scheduling tool.\nAnd of course, if you could help me with a star, it would be amazing.\
# ...

# %%
from langchain_openai.chat_models.azure import AzureChatOpenAI

client = AzureChatOpenAI(
    azure_endpoint="https://baroni-oai-dio-bootcamp-dev-eastus-001.openai.azure.com/",
    api_key="",
    api_version="2024-02-15-preview",
    deployment_name="gpt-40-mini",
    max_retries=0
)

def translate_article(text, lang):
    messages = [
        ("system", "Você atua como tradutor de textos"),
        ("user", f"traduza o {text} para o idioma {lang} e responda em markdown")
    ]

    response = client.invoke(messages)
    print(response.content)
    return response.content

translate_article("let's see if the deployment was succeeded", "portugues")
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# <ipython-input-34-37ff4ee21c3f> in <cell line: 21>()
#      19     return response.content
#      20
# ---> 21 translate_article("let's see if the deployment was succeeded", "portugues")
#
# <ipython-input-34-37ff4ee21c3f> in translate_article(text, lang)
#      15     ]
#      16
# ---> 17     response = client.invoke(messages)
#      18     print(response.content)
#      19     return response.content
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/language_models/chat_models.py in invoke(self, input, config, stop, **kwargs)
#     284         return cast(
#     285             ChatGeneration,
# --> 286             self.generate_prompt(
#     287                 [self._convert_input(input)],
#     288                 stop=stop,
#
# ...

# %%
url1 = 'https://dev.to/kenakamu/azure-open-ai-in-vnet-3alo'
text = extract_text_from_url(url1)
article = translate_article(text, "pt-br")
print(article)
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# <ipython-input-28-24e4b553c803> in <cell line: 3>()
#       1 url1 = 'https://dev.to/kenakamu/azure-open-ai-in-vnet-3alo'
#       2 text = extract_text_from_url(url1)
# ----> 3 article = translate_article(text, "pt-br")
#       4 print(article)
#
# <ipython-input-27-36376c04bdad> in translate_article(text, lang)
#      15     ]
#      16
# ---> 17     response = client.invoke(messages)
#      18     print(response.content)
#      19     return response.content
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/language_models/chat_models.py in invoke(self, input, config, stop, **kwargs)
#     284         return cast(
#     285             ChatGeneration,
# --> 286             self.generate_prompt(
#     287                 [self._convert_input(input)],
#     288                 stop=stop,
#
# ...
